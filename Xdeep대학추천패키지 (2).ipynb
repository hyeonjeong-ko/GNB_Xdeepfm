# %% [markdown]
# # module & data import

# %%
# !pip install deepctr
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deepctr in /home/work/.local/lib/python3.8/site-packages (0.9.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from deepctr) (2.27.1)
# Requirement already satisfied: h5py==2.10.0 in /home/work/.local/lib/python3.8/site-packages (from deepctr) (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from h5py==2.10.0->deepctr) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.8/dist-packages (from h5py==2.10.0->deepctr) (1.21.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.8/dist-packages (from requests->deepctr) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->deepctr) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->deepctr) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->deepctr) (3.3)
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from keras_preprocessing.sequence import pad_sequences
from deepctr.feature_column import SparseFeat, VarLenSparseFeat, get_feature_names
from deepctr.models.xdeepfm import xDeepFM
from sklearn.model_selection import train_test_split

# %%
# importing libraries
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from deepctr.models import xDeepFM
from deepctr.feature_column import SparseFeat, DenseFeat,get_feature_names

from functools import reduce
import operator
from collections import Counter
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# compiling the model
import tensorflow as tf

# %%
def choose_univ(univ_name):
    if(univ_name == "University of Michigan"):
        res = univlog_1
    elif(univ_name == "University of California Berkeley"):
        res = univlog_2
    elif(univ_name == "George Washington University"):
        res = univlog_3
    return res

# %%
 # 최종 input data 생성(df)
def data_pca(data):
    # 차원축소할 data
    dense_features = ['catev_' + str(i) for i in range(1,80)]
    dense_features2 = [str(i) for i in range(1,80)]
    dense_features.extend(dense_features2)
    
    # PCA 적용 - 컴포넌트는 1로 설정합니다.
    df_scaled = StandardScaler().fit_transform(data[dense_features])


    pca = PCA(n_components=5)
    #fit( )과 transform( ) 을 호출하여 PCA 변환 데이터 반환
    pca.fit(df_scaled)
    df_pca = pca.transform(df_scaled)
    
    df = pd.DataFrame(df_pca,columns=['pca_vector' + str(i) for i in range(1,6)]) # 차원축소 dataframe생성
    
    tmpcol =  ["title","isbn","author", "publisher","date",'label','Cn_1','Cn_2','Cn_3','Cn_4']
    df[tmpcol] = data[tmpcol]
    return df

# %%
def Xdeep_encoding(data):
    # data inputation for missing values
    data[sparse_features] = data[sparse_features].fillna('-1',)

    # encoding function  // labelencoder ; 문자를 0부터 증가하는 정수형 숫자로 바꿔주는기능을 제공
    def encoding(data,feat,encoder):
        data[feat] = encoder.fit_transform(data[feat])

    # encoding for categorical feautures
    [encoding(data, feat, LabelEncoder()) for feat in sparse_features]

    # 1.Label Encoding for sparse features
    for feat in sparse_features:
      lbe = LabelEncoder()
      data[feat] = lbe.fit_transform(data[feat])
    
    return data

# %%
def return_ctr():
    #predicting
    pred_ans_xdeep_test = model.predict(test_model_input, batch_size=256)
    #predicting
    pred_ans_xdeep_train = model.predict(train_model_input, batch_size=256)
    test['pred_ctr'] = pred_ans_xdeep_test
    train['pred_ctr'] = pred_ans_xdeep_train
    ctr = pd.concat([train,test])
    ctr_sorted = ctr.sort_values(by=ctr.columns[-1],ascending=False)
    return ctr_sorted # final data

# %%
def Cn3_filtering():
    # gnb에서 검색 로그찾기
    gnb_univ = gnb[gnb['company_name'].str.contains(univname)]
    user_log_cn3 = gnb_univ['Cn_3'].values.tolist() # user_log_cn3 ; user가 검색한 책들의 Cn3_list
    counter = Counter(user_log_cn3)
    keycount = dict(counter)
    sorted_cn3 = sorted(keycount.items(), reverse=True,key=lambda item: item[1])
    
    cn3_user_interestd = dict(sorted_cn3[:3])
    
    userlike = ctr_sorted['Cn_3'].isin(cn3_user_interestd)
    like = ctr_sorted[userlike]
    return like # 유저가 가장 관심있는 카테고리

# %%
# all data import
univlog_1 = pd.read_csv('univlog_1.csv')
univlog_2 = pd.read_csv('univlog_2.csv')
univlog_3 = pd.read_csv('univlog_3.csv')
gnb = pd.read_csv('gnbgnb.csv') # user검색 Cn3 빈도수 얻기 위해 import

# %%
univ1_recommend = pd.read_csv('univ1_recommend.csv')
univ2_recommend = pd.read_csv('univ2_recommend.csv')
univ3_recommend = pd.read_csv('univ3_recommend.csv')

# %% [markdown]
# # University1에 대한 추천 결과

# %%
cn3_univ1_list = univlog_1['Cn_3'].values.tolist()

# %%
def Cn3_filtering(univname):
    # gnb에서 검색 로그찾기
    gnb_univ = gnb[gnb['company_name'].str.contains(univname)]
    user_log_cn3 = gnb_univ['Cn_3'].values.tolist() # user_log_cn3 ; user가 검색한 책들의 Cn3_list
    counter = Counter(user_log_cn3)
    keycount = dict(counter)
    sorted_cn3 = sorted(keycount.items(), reverse=True,key=lambda item: item[1])
    
    return sorted_cn3

# %%
u1  = Cn3_filtering('University of Michigan')

# %%
gnb[gnb['company_name']=='George Washington University']
# Out:
#                isbn     Cn_1   Cn_2        Cn_3        Cn_4  \
# 2315  9791130421018   한국소개도서  한국어학습    한국어학습 일반    한국어학습 일반
# 2316  9791130420004   한국소개도서  한국어학습    한국어학습 일반    한국어학습 일반
# 2317  9791186610701   한국소개도서  한국어학습    한국어학습 일반    한국어학습 일반
# 2318  9791190630825    시/에세이  테마에세이       그림에세이       그림에세이
# 2319  9791190908221  어린이(초등)  어린이문학         그림책        한국작가
# 2320  9791156620495       소설   한국소설      한국소설일반      한국소설일반
# 2321  9791156620679       소설   한국소설      한국소설일반      한국소설일반
# 2322  9788994006734       소설   한국소설      한국소설일반      한국소설일반
# 2323  9791156620181       소설   한국소설      한국소설일반      한국소설일반
# 2324  9788994006949       소설   한국소설      한국소설일반      한국소설일반
# 2325  9788993454659       인문    언어학         국어학       국어이야기
# 2326  9788943307844  어린이(초등)  어린이문학         동화책        외국작가
# 2327  9788954640343  어린이(초등)  어린이문학       동시/동요       동시/동요
# 2328  9788927732273   한국소개도서  한국어학습    한국어학습 일반    한국어학습 일반
# 2329  9781635190250   한국소개도서  한국어학습  영어권 사용자 대상  영어권 사용자 대상
# 2330  9781635190199   한국소개도서  한국어학습  영어권 사용자 대상  영어권 사용자 대상
# 2331  9781635190243   한국소개도서  한국어학습  영어권 사용자 대상  영어권 사용자 대상
# 2332  9781635190151   한국소개도서  한국어학습  영어권 사용자 대상  영어권 사용자 대상
# 2333  9781635190168   한국소개도서  한국어학습  영어권 사용자 대상  영어권 사용자 대상
#
#                                                   title  \
# 2315                    외국인을 위한 한국어 읽기 세트 1(1-50)(전50권)
# 2316                           외국인을 위한 한국어 읽기 세트(전100권)
# 2317                                       게임으로 배우는 한국어
# 2318  편안하고 사랑스럽고 그래 세트(20만부 판매기념 영문수록 개정판)(양장본 HardC...
# 2319      달에서 아침을(Breakfast On The Moon)(양장본 HardCover)
# 2320                       바이링궐 에디션 한국 대표 소설 세트 6(전15권)
# 2321                       바이링궐 에디션 한국 대표 소설 세트 7(전20권)
# 2322                       바이링궐 에디션 한국 대표 소설 세트 2(전15권)
# 2323                       바이링궐 에디션 한국 대표 소설 세트 5(전15권)
# 2324                       바이링궐 에디션 한국 대표 소설 세트 3(전15권)
# 2325                한국어 경어법의 기능과 사용 원리(한국어 경어법 연구 총서 3)
# 2326                섬(어른과 아이가 함께 보는 그림책)(양장본 HardCover)
# 2327                        달에서 온 아이 엄동수(양장본 HardCover)
# 2328                                    역사 이야기로 배우는 한국어
# 2329                      Learning Korean Through Tasks
# 2330                      Anytime Korean Intermediate 1
# 2331                      Anytime Korean Intermediate 2
# 2332                         Anytime Korean Beginning 1
# 2333                         Anytime Korean Beginning 2
#
#                                                  author     publisher  \
# 2315                                           한국어읽기연구회    "학이시습\r"\r
# 2316                                           한국어읽기연구회    "학이시습\r"\r
# 2317                                                김대옥      "하우\r"\r
# 2318                                                 퍼엉  "위즈덤하우스\r"\r
# 2319                                                이수연  "위즈덤하우스\r"\r
# 2320                                          이외수 외 14인     "아시아\r"\r
# 2321                                                 이상     "아시아\r"\r
# 2322                                                이문열     "아시아\r"\r
# 2323  김주영, 윤영수, 정지아, 윤성희, 백가흠, 오수연, 강영숙, 편혜영, 부희령, 윤...     "아시아\r"\r
# 2324  김소진, 하성란, 조경란, 박민규, 김애란, 이문구, 박범신, 송기원, 성석제, 박...     "아시아\r"\r
# 2325                                                이정복      "소통\r"\r
# 2326                                             아민 그레더      "보림\r"\r
# 2327                                                 김륭    "문학동네\r"\r
# 2328                                                김순례     "다락원\r"\r
# 2329  YouJin Kim, Bumyong Choi, Hyunae Yun, Binna Ki...     "공앤박\r"\r
# 2330             Sangbok Kim, Sang-Seok Yoon, Jieun Kim     "공앤박\r"\r
# 2331             Sangbok Kim, Sang-Seok Yoon, Jieun Kim     "공앤박\r"\r
# 2332          Sangbok Kim, Jaemin Roh, Danielle O. Pyun     "공앤박\r"\r
# 2333          Sangbok Kim, Jaemin Roh, Danielle O. Pyun     "공앤박\r"\r
#
#                       company_name
# 2315  George Washington University
# 2316  George Washington University
# 2317  George Washington University
# 2318  George Washington University
# 2319  George Washington University
# 2320  George Washington University
# 2321  George Washington University
# 2322  George Washington University
# 2323  George Washington University
# 2324  George Washington University
# 2325  George Washington University
# 2326  George Washington University
# 2327  George Washington University
# 2328  George Washington University
# 2329  George Washington University
# 2330  George Washington University
# 2331  George Washington University
# 2332  George Washington University
# 2333  George Washington University

# %%
univlog_1[univlog_1['label']==1]
# Out:
#          catev_0   catev_1   catev_2   catev_3   catev_4   catev_5   catev_6  \
# 3      -0.079808  0.125609 -0.159979 -0.060015  0.081533 -0.066703  0.242454
# 4       0.172614 -0.076462  0.229195  0.080075  0.038470  0.082090  0.004960
# 5      -0.315710  0.076397  0.177348 -0.072059 -0.177550 -0.015722  0.080511
# 6      -0.069553 -0.088084  0.021067  0.156897 -0.275213  0.102563  0.309198
# 7      -0.230791 -0.008921  0.176785 -0.067517 -0.154258 -0.128113  0.041399
# ...          ...       ...       ...       ...       ...       ...       ...
# 977125 -0.092156  0.106429  0.079686  0.236358 -0.299829 -0.234260  0.172575
# 977126 -0.192142 -0.076433  0.204359  0.310382 -0.264715 -0.140418  0.233044
# 977127 -0.046551 -0.099631 -0.001914  0.293664 -0.006692 -0.215677  0.443788
# 977128 -0.279428 -0.000029  0.091306  0.318108 -0.275840  0.077868  0.006554
# 977133  0.098143 -0.128666  0.295212  0.082682 -0.098925  0.112891  0.006185
#
#          catev_7   catev_8   catev_9  ...  Cn_1    Cn_2    Cn_3      Cn_4  \
# 3       0.133134 -0.482992  0.177329  ...  정치사회  사회문제복지    노동문제    노동문제일반
# 4       0.132072 -0.410798 -0.079386  ...  시에세이     한국시     현대시       현대시
# 5       0.089199 -0.286602 -0.159661  ...    인문   한국문학론  한국고전문학    구비문학설화
# 6       0.003851 -0.179723 -0.199098  ...  역사문화     한국사     개화기  민족운동민족주의
# 7       0.106022 -0.257254 -0.035747  ...    인문   한국문학론  한국고전문학    구비문학설화
# ...          ...       ...       ...  ...   ...     ...     ...       ...
# 977125  0.062418 -0.133733 -0.008069  ...    만화      만화      만화        만화
# 977126  0.103522 -0.210167 -0.089047  ...    만화   스포츠만화   스포츠만화     스포츠만화
# 977127 -0.041648 -0.279552 -0.080476  ...    만화      만화      만화        만화
# 977128  0.029926 -0.390990 -0.068946  ...    만화      만화      만화        만화
# 977133  0.187094 -0.373396 -0.110085  ...    만화      만화      만화        만화
#
#         author_publisher  label                        title  \
# 3           안또니오 네그리갈무리     1.0                  디오니소스의 노동 1
# 4                표성배갈무리     1.0                    아침햇살이 그립다
# 5           김현룡건국대학교출판부     1.0                     한국문헌설화 2
# 6           조일문건국대학교출판부     1.0                     한국독립운동문류
# 7           김현룡건국대학교출판부     1.0                     한국문헌설화 4
# ...                  ...    ...                          ...
# 977125            대원씨아이     1.0         순정 로맨티카 7(B애+코믹스 63)
# 977126            대원씨아이     1.0                 크로스 게임 9(2판)
# 977127            대원씨아이     1.0      순정 로맨티카 10(비애+ 코믹스 138)
# 977128     우메자와 하나대원씨아이     1.0  사랑과 욕망은 학교에서 6(비애+ 코믹스 139)
# 977133      몬치 카오리대원씨아이     1.0  학생회장님께 충고 3(비애 코믹스 B愛∞ 023)
#
#                    author  publisher            company_name
# 3                안또니오 네그리       갈무리   University of Michigan
# 4                     표성배       갈무리   University of Michigan
# 5                     김현룡  건국대학교출판부   University of Michigan
# 6                     조일문  건국대학교출판부   University of Michigan
# 7                     김현룡  건국대학교출판부   University of Michigan
# ...                   ...        ...                     ...
# 977125  SHUNGIKU NAKAMURA     대원씨아이   University of Michigan
# 977126     Adachi Mitsuru     대원씨아이   University of Michigan
# 977127  SHUNGIKU NAKAMURA     대원씨아이   University of Michigan
# 977128            우메자와 하나     대원씨아이   University of Michigan
# 977133             몬치 카오리     대원씨아이   University of Michigan
#
# [353302 rows x 350 columns]

# %%
u1
# Out:
# [('한국소설일반', 209),
#  ('한국에세이', 120),
#  ('한국문학이론', 76),
#  ('인문교양', 66),
#  ('영어권 사용자 대상', 58),
#  ('현대시', 43),
#  ('정부간행물', 41),
#  ('개화기', 39),
#  ('성악/가곡', 38),
#  ('SF/과학소설', 37),
#  ('외교/국제관계', 37),
#  ('각국정치', 35),
#  ('한국역사인물', 34),
#  ('조선시대', 33),
#  ('사회학일반', 33),
#  ('한국어학습 일반', 33),
#  ('문학비평/평론', 30),
#  ('각국사회/문화', 29),
#  ('정치일반', 29),
#  ('기독교인물', 28),
#  ('회화', 26),
#  ('여성학/남성학', 23),
#  ('사회문제', 22),
#  ('근현대사', 22),
#  ('한국', 20),
#  ('법학일반', 20),
#  ('한국일반', 20),
#  ('국어학', 20),
#  ('동양사일반', 18),
#  ('영화이야기', 17),
#  ('한국통사', 17),
#  ('정치가', 17),
#  ('역사/문화/인물', 17),
#  ('신앙생활', 16),
#  ('한국철학', 16),
#  ('한국문화예술', 16),
#  ('기독교일반', 15),
#  ('한국고전문학', 15),
#  ('고전소설/문학선', 15),
#  ('신학/기독교사상', 15),
#  ('한국작가론', 14),
#  ('동화책', 14),
#  ('예술사', 13),
#  ('한국고대사', 13),
#  ('사회사상', 12),
#  ('교양미술', 12),
#  ('교회', 12),
#  ('역사/대하소설', 12),
#  ('노동문제', 11),
#  ('통일관련', 11),
#  ('교과교육과정', 11),
#  ('미스터리/스릴러소설', 11),
#  ('기도/설교/전도', 10),
#  ('일본사', 10),
#  ('사회학이론', 10),
#  ('경제전망', 10),
#  ('일본문학이론', 10),
#  ('한국문학', 9),
#  ('지방/향토', 9),
#  ('언론이론', 8),
#  ('동화/그림책/리더스', 8),
#  ('인문교양총서일반', 8),
#  ('건축작품/건물', 8),
#  ('민속학', 7),
#  ('한국역사', 7),
#  ('예술이야기', 7),
#  ('예술가이야기', 7),
#  ('글쓰기', 7),
#  ('소설론', 7),
#  ('삼국시대', 7),
#  ('교육학이론', 7),
#  ('청소년 인문교양', 7),
#  ('국악', 7),
#  ('행정학', 7),
#  ('건축디자인', 7),
#  ('무용이론', 6),
#  ('무용일반/무용평론', 6),
#  ('이민', 6),
#  ('영화이론', 6),
#  ('만화', 6),
#  ('세계사이야기', 6),
#  ('한국문화사', 6),
#  ('만화/애니메이션', 6),
#  ('한국안보', 6),
#  ('한국요리', 6),
#  ('기독교역사', 5),
#  ('미술사', 5),
#  ('교양심리', 5),
#  ('방송/신문', 5),
#  ('광고/홍보/브랜드', 5),
#  ('지방자치', 5),
#  ('한문학', 5),
#  ('연극이론', 5),
#  ('아동문학론', 5),
#  ('한국그림책', 5),
#  ('인문학의이해', 5),
#  ('명시모음', 5),
#  ('문학이론일반', 4),
#  ('한국무용', 4),
#  ('중국사', 4),
#  ('교육에세이', 4),
#  ('국방/군사일반', 4),
#  ('언어학일반', 4),
#  ('교양음악', 4),
#  ('젠더', 4),
#  ('문학의이해', 4),
#  ('여러인물/인터뷰', 4),
#  ('헌법', 4),
#  ('불교경전', 4),
#  ('한국경제', 4),
#  ('한복', 4),
#  ('동남아시아사', 4),
#  ('장애인복지', 3),
#  ('로맨스소설', 3),
#  ('공포/호러소설', 3),
#  ('불교일반', 3),
#  ('언론일반', 3),
#  ('문화재/유산', 3),
#  ('유적/유물', 3),
#  ('고문서', 3),
#  ('독서', 3),
#  ('사회교육/평생교육', 3),
#  ('한국역사기행', 3),
#  ('선거', 3),
#  ('교양세계사', 3),
#  ('음식문화', 3),
#  ('연기/작가/연출', 3),
#  ('시론', 3),
#  ('청소년 과학/컴퓨터', 3),
#  ('교양철학', 3),
#  ('페미니즘문학론', 3),
#  ('국내사진집', 3),
#  ('연극이야기', 3),
#  ('공연예술', 3),
#  ('교육행정/교육경영', 3),
#  ('동양고전', 3),
#  ('정치사상', 3),
#  ('정치이론', 3),
#  ('대중음악', 3),
#  ('남북관계', 3),
#  ('일상생활/드라마/가족만화', 3),
#  ('범우문고', 3),
#  ('무속/민간신앙', 2),
#  ('세계문화사', 2),
#  ('명언/지혜', 2),
#  ('그림에세이', 2),
#  ('사회문화', 2),
#  ('한국신화', 2),
#  ('영화사', 2),
#  ('출판', 2),
#  ('문학사', 2),
#  ('사회복지', 2),
#  ('아이디어/창의성', 2),
#  ('동양철학일반', 2),
#  ('원불교', 2),
#  ('건축가', 2),
#  ('주제별철학', 2),
#  ('미래학', 2),
#  ('고고학', 2),
#  ('교육사', 2),
#  ('독도문제', 2),
#  ('동양문화사', 2),
#  ('경영전략일반', 2),
#  ('심리치료', 2),
#  ('정책학', 2),
#  ('일상생활/드라마', 2),
#  ('민법', 2),
#  ('문학교육', 2),
#  ('서지학', 2),
#  ('예술론', 2),
#  ('경찰/경호', 2),
#  ('미술실기/기법', 2),
#  ('주택/전원주택', 2),
#  ('판타지소설', 2),
#  ('음악이론', 2),
#  ('미술이론', 2),
#  ('포토에세이', 2),
#  ('고려시대', 2),
#  ('드라마/시나리오', 2),
#  ('일기/편지', 2),
#  ('철학에세이', 2),
#  ('러시아사', 2),
#  ('역사이야기', 2),
#  ('천도교', 2),
#  ('한국종교학', 2),
#  ('일본소설일반', 2),
#  ('빛깔있는 책들', 2),
#  ('건축론/비평', 1),
#  ('영미소설일반', 1),
#  ('상법', 1),
#  ('명상/치유에세이', 1),
#  ('청소년 역사', 1),
#  ('부동산', 1),
#  ('사회적기업', 1),
#  ('한길그레이트북스', 1),
#  ('발해', 1),
#  ('통역', 1),
#  ('유럽여행', 1),
#  ('중국문학이론일반', 1),
#  ('디자인', 1),
#  ('인류학', 1),
#  ('지리이야기', 1),
#  ('자원/에너지', 1),
#  ('애니메이션일반/만화영화', 1),
#  ('책세상문고 우리시대', 1),
#  ('문화유적답사', 1),
#  ('아시아문학이론', 1),
#  ('주거문화', 1),
#  ('조직관리', 1),
#  ('불교선/깨달음', 1),
#  ('기술공학일반', 1),
#  ('경영관리/기업경영', 1),
#  ('영어사전', 1),
#  ('답사여행', 1),
#  ('국내희곡작품', 1),
#  ('그림책', 1),
#  ('문인/작가론', 1),
#  ('드라마/영화소설', 1),
#  ('대중예술', 1),
#  ('국내경영이야기', 1),
#  ('기타도서관', 1),
#  ('청소년 시', 1),
#  ('대화/화술', 1),
#  ('건반악기', 1),
#  ('종교이야기', 1),
#  ('세계역사인물', 1),
#  ('통일신라', 1),
#  ('번역', 1),
#  ('영미문학이론일반', 1),
#  ('시민사회', 1),
#  ('가족복지', 1),
#  ('교양건축/건축이야기', 1),
#  ('신화의이해', 1),
#  ('식품학', 1),
#  ('스포츠일반', 1),
#  ('도시', 1),
#  ('여성처세', 1),
#  ('경제학일반', 1),
#  ('일본에세이', 1),
#  ('힌두교', 1),
#  ('댄스스포츠/에어로빅', 1),
#  ('한국전쟁', 1),
#  ('원예/작물학/임학', 1),
#  ('인공지능', 1),
#  ('예술여행', 1),
#  ('농수산일반', 1),
#  ('야구', 1),
#  ('살림지식총서', 1),
#  ('체육/스포츠이론', 1),
#  ('가톨릭일반', 1),
#  ('풍속/민속학일반', 1),
#  ('기타나라/여러나라시', 1),
#  ('예술/실용', 1),
#  ('의료인', 1),
#  ('정치경제학', 1),
#  ('과학이야기', 1),
#  ('전통음식,김치', 1),
#  ('환경구성/도안', 1),
#  ('고전에서배우는리더십', 1),
#  ('소비자/고객/CS', 1),
#  ('영미에세이', 1),
#  ('시조/한시(고전)', 1),
#  ('연설/스피치', 1),
#  ('그래픽노블일반', 1),
#  ('복음성가/CCM 음반', 1),
#  ('국내여행일반', 1),
#  ('자기관리/처세', 1),
#  ('종교학이론', 1),
#  ('서양철학일반', 1),
#  ('청소년 진로/직업', 1),
#  ('국제법', 1),
#  ('가정윤리/효', 1),
#  ('스포츠만화', 1),
#  ('전통무용', 1),
#  ('학습만화', 1),
#  ('청소년 예술/문화', 1),
#  ('사진실기', 1),
#  ('한국지리', 1),
#  ('경상도', 1),
#  ('청소년 에세이', 1),
#  ('복식사', 1),
#  ('문명/문명사', 1),
#  ('지식인마을', 1),
#  ('불교철학/사상', 1),
#  ('고전/전래동화/명작동화', 1),
#  ('캘리그래피', 1),
#  ('서예', 1),
#  ('서양철학자', 1),
#  ('자본론', 1),
#  ('가정관리학', 1),
#  ('역사기행일반', 1),
#  ('성경학습', 1),
#  ('역사만화', 1),
#  ('인문/사회', 1),
#  ('한국음식', 1)]

# %%
univ1_recommend
# Out:
#     pca_vector1  pca_vector2  pca_vector3  pca_vector4  pca_vector5  \
# 0      2.129046     3.212377    -2.504899    -2.894179    -3.986211
# 1      0.605042    -1.500557    -2.866050    -2.654450     4.686268
# 2      1.482597    -0.654120     0.144198     2.506013    -0.129607
# 3     -0.521815     5.809359    -0.352021     0.236670    -1.535210
# 4     -2.264689     3.088413    -0.624350    -4.089628     5.488279
# 5     -3.875617    -0.183625    -1.985201    -0.903870     1.249136
# 6      0.205663     0.653305    -1.266375     1.792072    -0.097354
# 7     -0.865559     2.555728    -2.572968     0.858490    -0.705410
# 8     -2.109207    -0.674217     3.285004     0.619337    -1.317819
# 9      1.042439     3.902969    -1.162819     0.597238    -0.477257
# 10     2.372709     1.652338    -0.567484    -0.632284     1.236636
# 11     3.757543     1.582021     0.271407     4.678127     0.337224
# 12     1.828521    -0.239307     2.958225    -2.196873     4.788382
# 13     0.469459     0.661787    -1.425635    -1.604353     1.750140
# 14     1.431272     2.026710    -0.858964    -2.613808     4.833608
# 15    -0.542230    -2.268461    -4.556259    -0.336695    -0.547845
# 16     0.322325     0.292848     0.555631    -1.149217    -0.912615
# 17     2.711721     1.325182    -2.758588     2.435883     1.693893
# 18    -3.921915     0.808253    -1.209088     0.666476    -1.110640
# 19     3.973084     0.266441    -2.983675    -0.480741    -1.093126
# 20     0.123822     3.927056    -0.877496    -1.153761     1.602234
# 21    -0.467408     3.404330    -0.636170    -1.826496     5.035679
# 22    -0.392933     2.369173    -0.518661    -0.511522    -1.147645
# 23     1.170008     1.316811     0.246080     0.341521    -0.586608
# 24    -1.501039     1.292613    -2.119446    -3.910526     5.230313
# 25     1.924699    -1.343890     0.223312    -1.892994    -0.074974
# 26    -0.168770    -1.053799    -1.010715    -0.052714     0.699197
# 27     0.363131    -1.579104    -0.895986    -1.045247     0.386069
# 28     5.146142     2.241042    -0.276522    -1.065598    -2.315878
# 29     0.212472    -2.895526     0.694584    -0.677044    -1.695046
#
#                                            title    isbn  author  publisher  \
# 0          고승열전 25(석우 대종사)(천치도 되지 말고 원숭이도 되지 말라)  476746  170932      16877
# 1                         곽예의 사진일기(문학과 사람 총서 10)  935650   41059       8622
# 2                                     선생님 나의 선생님  562120   35092      18164
# 3                    지금 여기에서 감사하라(양장본 HardCover)  556663  125160       2522
# 4                                 나의 꿈, 들국화 동산 2  407547  175807       8820
# 5                                 이판사판 역사판(큰글씨책)  902658  213678      15674
# 6                              겉,짓,말(결코 시시하지 않은)  181091  166459       4080
# 7                          염치와 수치(양장본 HardCover)  755052   50194       4566
# 8                                  그렇게 초등 엄마가 된다  299907  181595       2262
# 9                     이 외출이 행복하기를(양장본 HardCover)  813250  203402       8547
# 10                                        인연의 언덕  658148   53823       3627
# 11                                        자유의 선택  581694  162280      23017
# 12                                        골든아워 2  404265  172955      25649
# 13                                      천재토끼 차상문  261604   50194       8634
# 14                                      내 마음의 화첩  308867  189530       5235
# 15                                          파리일기  263787  200660       8634
# 16                      수탉도 수탉나름(현대수필가 100인선 90)  322563   57633      19393
# 17                                        모범 경작생  462986  105159      12650
# 18                                           책방뎐  970272  184317      16373
# 19                                      감자꽃 필 무렵  924207  105444       8237
# 20                                        칼럼 윤문칠  768041  169066      24644
# 21                시의 깊이갈이와 응축의 묘미(양장본 HardCover)  147092  255560       3491
# 22                         러브 노이즈(양장본 HardCover)  192213   63798       9152
# 23                                        지켜진 약속  575762  108715       8820
# 24                   일상의 자유를 그리며(수필문학사 수필선집 481)  493471  198565       3264
# 25                                   나른한 오후의 마들렌  584526  107567       7576
# 26                                       더 늦기 전에  310010  128891      19010
# 27  정이현: 트렁크(In the Trunk)(바이링궐 에디션 한국 대표 소설 25)  630388  202098      14262
# 28                                        이스크라 1  505882  247180       8429
# 29                            내 낚싯대 위에 내려앉은 나비 떼  762880  175226      24836
#
#     date  label  Cn_1     Cn_2    Cn_3     Cn_4  pred_ctr
# 0     46    1.0    소설     한국소설  한국소설일반   한국소설일반       1.0
# 1     58    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 2     39    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 3     47    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 4     53    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 5     60    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 6     56    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 7     57    1.0    인문    한국문학론  한국문학이론  한국근대문학론       1.0
# 8     56    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 9     57    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 10    49    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 11    42    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 12    56    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 13    48    1.0    소설     한국소설  한국소설일반   한국소설일반       1.0
# 14    51    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 15    56    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 16    49    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 17    43    1.0    소설     한국소설  한국소설일반   한국소설일반       1.0
# 18    59    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 19    59    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 20    57    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 21    51    1.0    인문    한국문학론  한국문학이론   한국현대시론       1.0
# 22    59    1.0    소설     한국소설  한국소설일반   한국소설일반       1.0
# 23    46    1.0    소설     한국소설  한국소설일반   한국소설일반       1.0
# 24    59    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 25    52    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 26    56    1.0  시에세이  나라별 에세이   한국에세이    한국에세이       1.0
# 27    51    1.0    소설     한국소설  한국소설일반   한국소설일반       1.0
# 28    34    1.0    소설     한국소설  한국소설일반   한국소설일반       1.0
# 29    58    1.0    소설     한국소설  한국소설일반   한국소설일반       1.0

# %% [markdown]
# # University2에 대한 추천 결과

# %%
u2  = Cn3_filtering('University of California Berkeley')

# %%
u2
# Out:
# [('한국문학이론', 13),
#  ('조선시대', 11),
#  ('근현대사', 6),
#  ('한국역사인물', 5),
#  ('통일관련', 5),
#  ('각국사회/문화', 4),
#  ('국어학', 4),
#  ('한국작가론', 4),
#  ('개화기', 4),
#  ('각국정치', 3),
#  ('한국소설일반', 3),
#  ('한국고전문학', 3),
#  ('한국철학', 3),
#  ('예술사', 2),
#  ('동양사일반', 2),
#  ('삼국시대', 2),
#  ('문명/문명사', 2),
#  ('외교/국제관계', 1),
#  ('한국전쟁', 1),
#  ('영미에세이', 1),
#  ('인문교양', 1),
#  ('국내사진집', 1),
#  ('도서관경영/운영', 1),
#  ('여성학/남성학', 1),
#  ('사회학일반', 1),
#  ('독서', 1),
#  ('민법', 1),
#  ('번역', 1),
#  ('동양고전', 1),
#  ('현대시', 1),
#  ('남북관계', 1),
#  ('영화감독/제작', 1),
#  ('서지학', 1),
#  ('일본사', 1),
#  ('한국종교학', 1),
#  ('한국에세이', 1),
#  ('정치일반', 1),
#  ('고전소설/문학선', 1),
#  ('사회사상', 1),
#  ('북한사', 1),
#  ('지방/향토', 1),
#  ('가톨릭일반', 1),
#  ('금융경제', 1)]

# %%
univ2_recommend
# Out:
#     pca_vector1  pca_vector2  pca_vector3  pca_vector4  pca_vector5  \
# 0      1.105552     1.944288    -2.548412     2.594673    -0.154575
# 1     -4.772080     3.722023    -2.728423     1.093178    -2.304848
# 2      0.222794     6.134292    -4.494244     0.142591    -1.821816
# 3      0.998460     3.885559    -0.902034    -0.849680    -1.672738
# 4     -2.247958     4.809062     0.983710     0.193994    -1.302591
# 5     -1.207405     3.163222    -0.678144     1.161898    -2.339493
# 6     -0.804103     4.697711    -0.860065    -0.768135    -0.681708
# 7      2.458300    -0.385740    -0.774771     3.137363     0.258319
# 8      1.404682     5.169987    -0.547978    -0.059985    -1.916838
# 9     -5.178662    -0.723405    -2.121084     0.201656    -0.324685
# 10    -2.022915     6.031992    -2.021923     0.704913    -0.101510
# 11    -3.622385     4.068634    -1.729912    -0.304911    -0.993413
# 12    -5.136437    -0.669971    -5.537983     1.997310    -0.282050
# 13    -1.580079     2.936616    -2.156375     1.196056    -2.259922
# 14    -4.653101     4.237206    -2.217702     0.747085     1.062039
# 15     2.274855     2.193620    -0.585301     0.937770    -1.595815
# 16    -1.985715     4.179633    -2.331713     1.451013    -0.987601
# 17    -3.004423     2.249369    -3.197849     2.618873     2.054493
# 18     0.320791     4.882173    -0.056123     0.309612    -2.237302
# 19    -3.175661    -0.054749    -3.192486     0.916118     1.719268
# 20    -2.506540     1.946670    -0.054038     6.439557     7.498142
# 21    -4.194967     4.262473    -2.619492     1.148829    -0.286506
# 22    -0.595443     5.405259    -0.652294     1.052959    -1.618518
# 23    -5.449439    -0.744775    -6.175674     1.198460     0.667572
# 24    -0.333856     4.461050    -2.237510    -0.117868    -1.440897
# 25    -5.118297    -0.100548    -3.849407     0.668414     3.049707
# 26    -2.634389     5.182596    -1.798228     2.191408    -0.179364
# 27    -3.950772     2.160087    -4.392237     1.209536    -3.976914
# 28    -3.992243     3.415167    -2.689005     2.809260     0.079668
# 29    -3.546804     1.991858    -1.510198     1.575896     0.062316
#
#                                                 title    isbn  author  \
# 0                                    헐버트의 꿈 조선은 피어나리!  658499   51229
# 1                                        조선시대 한일표류민연구  514555  247670
# 2                                     건건록(범우사상신서 051)   91202   96148
# 3                                     정도전을 위한 변명(개정판)  315229  209975
# 4                                             치마속 조선사  499414  127881
# 5                   100년을 울린 겔릭호의 고동소리(양장본 HardCover)  605348  124917
# 6             편역 사대문궤 2(동북아역사 자료총서 53)(양장본 HardCover)  358827  183181
# 7                 영국화가 엘리자베스 키스의 코리아 1920-1940 외(전3권)  592327  237109
# 8                                            왕을 위한 변명  178587  135482
# 9                                         2000년대 한국문학    3684  245338
# 10                     근현대 형성과정의 재인식 2(양장본 HardCover)  487269  198894
# 11                          최일남 소설어 사전(양장본 HardCover)  666319  100391
# 12                                       한국 현대 소설의 이해  530802   94883
# 13                                       시, 현대사를 관통하다  954652  177941
# 14     한국의 근대 문화장의 동역학(문화동역학 라이브러리 13)(양장본 HardCover)  285478  108503
# 15                                         난중일기와 오행 1  950942   50701
# 16          한국고전비평론 6: 조선 중 후기(한서대학교부설동양고전연구소국역총서 28)  151708  207238
# 17                                     서정주 시의 근대와 반근대  284837  225373
# 18                         임진왜란과 청주 의병(양장본 HardCover)  342954  177438
# 19                                    시를 읽는 천 개의 스펙트럼  665888   52797
# 20                  조선 풍속사 3: 조선 사람들 혜원의 그림 밖으로 걸어나오다  631656   32722
# 21      조선시대 차문화(백과사전류로 본)(한국사연구총서 73)(양장본 HardCover)  350691   66455
# 22                          조선왕조의 의궤와 왕실 행사(왕실문화총서 3)  170409   64596
# 23                                          한국 현대시 연구  487759  136749
# 24                                     표석을 따라 한성을 거닐다  956044  196231
# 25                                             문학의 이해  874419  103041
# 26  조선표류일기(부경대학교 인문사회과학연구소 해역인문학 자료총서 4)(양장본 HardC...  795030  126530
# 27                           한문학과 근대문학(양장본 HardCover)  327944  213920
# 28               채만식의 항일문학(서정시학 신서 38)(양장본 HardCover)  642620  223638
# 29                백석 시어의 힘(서정시학 신서 10)(양장본 HardCover)  607662  224293
#
#     publisher  date  label  Cn_1   Cn_2    Cn_3      Cn_4  pred_ctr
# 0       20195    57    1.0  역사문화    한국사    조선시대      조선후기       1.0
# 1        3491    39    1.0  역사문화    한국사    조선시대    조선시대일반       1.0
# 2        9658    32    1.0  역사문화    한국사    조선시대      조선후기       1.0
# 3       25603    52    1.0  역사문화    한국사    조선시대      조선전기       1.0
# 4       20397    47    1.0  역사문화    한국사    조선시대    조선시대일반       1.0
# 5       25114    45    1.0  역사문화    한국사    근현대사     한국근대사       1.0
# 6        6413    58    1.0  역사문화    한국사    조선시대      조선중기       1.0
# 7       20346    45    1.0  역사문화    한국사    조선시대    조선시대일반       1.0
# 8        4080    47    1.0  역사문화    한국사    조선시대     조선왕조사       1.0
# 9        8217    27    1.0    인문  한국문학론  한국문학이론  한국문학이론일반       1.0
# 10      19626    50    1.0  역사문화    한국사    근현대사    한국근현대사       1.0
# 11      19255    53    1.0    인문  한국문학론  한국문학이론   한국현대소설론       1.0
# 12       2685    48    1.0    인문  한국문학론  한국문학이론   한국현대소설론       1.0
# 13       8723    56    1.0    인문  한국문학론  한국문학이론    한국현대시론       1.0
# 14      12686    51    1.0  역사문화    한국사    근현대사     한국근대사       1.0
# 15      19019    54    1.0  역사문화    한국사    조선시대      조선중기       1.0
# 16       9138    49    1.0    인문  한국문학론  한국문학이론  한국문학이론일반       1.0
# 17      12686    41    1.0    인문  한국문학론  한국문학이론    한국근대시론       1.0
# 18      11889    52    1.0  역사문화    한국사    조선시대      조선중기       1.0
# 19      10379    49    1.0    인문  한국문학론  한국문학이론    한국현대시론       1.0
# 20      22522    48    1.0  역사문화    한국사    조선시대  조선시대생활문화       1.0
# 21       3491    47    1.0  역사문화    한국사    조선시대  조선시대생활문화       1.0
# 22      25116    56    1.0  역사문화    한국사    조선시대     조선왕조사       1.0
# 23      23603    37    1.0    인문  한국문학론  한국문학이론    한국현대시론       1.0
# 24      17418    56    1.0  역사문화    한국사    근현대사     한국근대사       1.0
# 25      15740    52    1.0    인문  한국문학론  한국문학이론  한국문학이론일반       1.0
# 26      12686    58    1.0  역사문화    한국사    조선시대      조선후기       1.0
# 27      21725    47    1.0    인문  한국문학론  한국문학이론   한국근대문학론       1.0
# 28      12093    51    1.0    인문  한국문학론  한국문학이론   한국근대문학론       1.0
# 29      12093    46    1.0    인문  한국문학론  한국문학이론    한국문학비평       1.0

# %% [markdown]
# # University3에 대한 추천 결과

# %%
u3  = Cn3_filtering('George Washington University')

# %%
u3
# Out:
# [('한국소설일반', 5),
#  ('영어권 사용자 대상', 5),
#  ('한국어학습 일반', 4),
#  ('그림에세이', 1),
#  ('그림책', 1),
#  ('국어학', 1),
#  ('동화책', 1),
#  ('동시/동요', 1)]

# %%
univ3_recommend
# Out:
#     pca_vector1  pca_vector2  pca_vector3  pca_vector4  pca_vector5  \
# 0      1.935706     0.235206     0.710018     1.412964     0.260800
# 1      3.173202    -0.208024    -1.757197    -0.775967    -1.191027
# 2     -2.744343     2.092725     1.506501    -0.597971    -0.712300
# 3      1.356014    -1.508156    -0.305334     2.158447    -0.335055
# 4     -0.580192    -3.444229    -4.317887    -1.861115    -0.781274
# 5      3.749245     3.465202     2.719297    -1.458173    -0.625947
# 6     -1.282464     3.006225    -1.874011    -1.342427    -2.074517
# 7     -0.594106    -1.487598    -0.603739     0.115345    -0.112581
# 8      2.416888     0.533023     2.555919     0.628297     5.253288
# 9      3.955223     2.151534     4.768111    -1.821003    -0.178147
# 10     3.461221     0.212363     0.265070    -0.041757    -0.477111
# 11     1.568646     0.539629    -0.752954    -1.714121    -1.219053
# 12    -0.225808     0.559887     0.092343     0.040423    -0.162046
# 13     2.523391     1.833538    -0.080478     0.330045    -0.418118
# 14     1.059902    -1.333570    -0.005270     0.387814    -1.464645
# 15     0.490583     1.162762    -0.827503     0.900599    -1.797349
# 16     3.366856    -1.225040     0.384095     1.041891    -2.951539
# 17    -6.240318    -1.370188     2.864375     1.831679    -0.322215
# 18     2.205904     4.150205    -1.747056     1.916519     0.108417
# 19    -0.802542     1.280801     1.738101     1.102426    -0.163277
# 20     4.115714    -1.084236     2.860119     3.057108     0.122652
# 21    -1.689337    -3.519032    -2.646467    -1.293564    -0.305025
# 22     0.272891     0.707443    -1.055922    -2.392168    -0.916622
# 23    -0.158370     2.663852    -1.524714     0.820137    -0.862360
# 24     0.204789     1.503743    -2.361865     2.942587    -1.305255
# 25    -4.114162    -0.782749     2.758078     0.031014     1.012689
# 26     1.442353     1.452805    -0.467993    -2.425679    -0.435358
# 27     1.178379     1.361047    -0.665698    -1.620075     4.890919
# 28     0.884278     1.819243    -1.101599     1.018793     3.880277
# 29    -0.097477     0.184106    -0.401362    -1.409769    -2.145183
#
#                                             title    isbn  author  publisher  \
# 0                                        남자의 길 10  118086   32610       7384
# 1                                          그림자 밟기  339095  103104       2961
# 2                    국민 한국어 1 세트(3판)(CD1장포함)(전2권)  493159  201150       3377
# 3                                       무엇을 할 것인가  514896  203471       2468
# 4                     문학으로 덕질하다(예술쟁이들)(나무소설가선 21)  767428  137133       8633
# 5                                      빨간 마후라 김영환  871719  218047      13358
# 6                           몌구리 일화(양장본 HardCover)  475790  112046       6548
# 7                                            코스미안  882469  197150      18572
# 8                                         수요일에 하자  721811  172836       5179
# 9                                     후계자 3: 대한민국  795753  181260      23254
# 10                                         호랑이 눈썹  360508   56567      25382
# 11                                         마흔의 온도  861688  174099      10192
# 12                        우리들의 작은 신(큰글자도서)(리더스 원)  820520  242075       9272
# 13                               어떤 그리고 또 다른 만남 2  837593  216142      19371
# 14                                           숨비소리  431437  103623      20438
# 15                                      사랑할 수 있었다  930670   96691       9301
# 16                                    카펜터의 위대한 여행  780139   65664      11589
# 17              표준 한국어 익힘책(고학년: 의사소통 3)(초등학생을 위한)  927649   42984       7719
# 18                             은비령(양장본 HardCover)  542043  178625      11754
# 19                                           가족 2  795688  181260      23254
# 20                                그대는 없고 그대의 껍질 2  445358  162146      18751
# 21                                           대학괴담  285804   60198      10391
# 22                                         퓨전 철학관  799632  108418      19765
# 23                                      걸어서라도 가리라  646548  168152      19520
# 24                      가만히 부르는 이름(양장본 HardCover)  806699  188771      23249
# 25  My Weekly Korean Vocabulary Book(매일매일 단어공부) 1  282827  215403       7396
# 26                                         빙이화(하)  326410  202446      24428
# 27                                   캐리어 끌기(큰글씨책)  862944  211794      11252
# 28                                     잃은 사람들의 만찬  606804   35332       8633
# 29                                         꽃잎처럼 5  296315  108767      18629
#
#     date  label    Cn_1   Cn_2        Cn_3        Cn_4  pred_ctr
# 0     51    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 1     55    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 2     54    1.0  한국소개도서  한국어학습    한국어학습 일반    한국어학습 일반       1.0
# 3     51    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 4     58    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 5     56    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 6     51    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 7     56    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 8     55    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 9     60    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 10    47    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 11    60    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 12    58    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 13    57    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 14    37    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 15    57    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 16    53    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 17    58    1.0  한국소개도서  한국어학습    한국어학습 일반    한국어학습 일반       1.0
# 18    43    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 19    54    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 20    33    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 21    48    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 22    54    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 23    50    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 24    58    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 25    53    1.0  한국소개도서  한국어학습  영어권 사용자 대상  영어권 사용자 대상       1.0
# 26    47    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 27    60    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 28    50    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
# 29    48    1.0      소설   한국소설      한국소설일반      한국소설일반       1.0
